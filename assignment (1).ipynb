# %%
#Write a python program to create an array and convert to a desired dimension.
desired dimension, as shown in picture.
import numpy as np
original_array = np.array([[8, 9, 10],[11, 12, 13]])
print("Original array:")
print(original_array)
reshaped_array = original_array.reshape(3, 2)
print("\nReshaped array:")
print(reshaped_array)
# Out:
# Original array:
# [[ 8  9 10]
#  [11 12 13]]
#
# Reshaped array:
# [[ 8  9]
#  [10 11]
#  [12 13]]

# %%
import numpy as np
arr = np.array([[8, 9],[10, 11],[12, 13]])
print("Original array:")
print(arr)
sliced_array = arr[[0, 1], [1, 1]]
print("\nSliced array:")
print(sliced_array)
# Out:
# Original array:
# [[ 8  9]
#  [10 11]
#  [12 13]]
#
# Sliced array:
# [ 9 11]

# %%
import pandas as pd
data = {'Country': ['Russia', 'Colombia', 'Chile', 'Ecuador', 'Nigeria'],'Rank': [121, 40, 100, 130, 11]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Colombia    40
# 2     Chile   100
# 3   Ecuador   130
# 4   Nigeria    11

# %%
#1.  Display the Glucose level and the Age for the samples having the index ranging from 45 to 60.
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('diabetes_model.csv')
glucose_age_subset = df.loc[45:60, ['Glucose', 'Age']]
print("\nGlucose level and Age for samples 45 to 60:")
glucose_age_subset
# Out:
# Glucose level and Age for samples 45 to 60:
#     Glucose  Age
# 45      137   21
# 46      145   70
# 47      113   22
# 48       96   27
# 49      131   26
# 50      113   21
# 51      120   34
# 52       95   24
# 53      155   46
# 54      100   46
# 55      184   49
# 56       90   29
# 57      142   61
# 58      125   27
# 59      101   26
# 60      188   22

# %%
#How many patients in the data are having the blood pressure level above 120?
bp_count = df[df['BloodPressure'] > 120].shape[0]
print("\nNumber of patients with blood pressure above 120:",bp_count)
# Out:
# Number of patients with blood pressure above 120: 1

# %%
# Find the minimum and maximum value of insulin level in the data
min_insulin = df['Insulin'].min()
max_insulin = df['Insulin'].max()
print("\nMinimum Insulin level:", min_insulin)
print("Maximum Insulin level:", max_insulin)
# Out:
# Minimum Insulin level: 0
# Maximum Insulin level: 846

# %%
# Create a histogram of "Age"
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=20, color='red', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['BMI'], df['Glucose'], alpha=0.5, color='green')
plt.title('Scatter Plot of BMI vs Glucose')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.show()
